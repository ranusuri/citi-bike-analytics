# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import glob
import os

# %%
# combine all 2022 monthly data files into single csv file
# merging the files
#files_joined = os.path.join('C:\\Users\\DELL\\OneDrive\\Desktop\\CSV_files', "salesdata*.csv")

# Return a list of all joined files
list_files = glob.glob("data/*.csv")

print("** Merging multiple csv files into a single pandas dataframe **")
# Merge files by joining all files
df = pd.concat(map(pd.read_csv, list_files), ignore_index=True)

print(df)
# Out:
# ** Merging multiple csv files into a single pandas dataframe **
#                  ride_id rideable_type           started_at  \
# 0       121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1       FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2       39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3       A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4       75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                  ...           ...                  ...
# 632814  13FE513C650901A3  classic_bike  2021-12-16 17:17:46
# 632815  CA29051F38E67D30  classic_bike  2021-12-07 17:10:29
# 632816  A719DEA143005404  classic_bike  2021-12-18 09:50:14
# 632817  D39126975208B59D  classic_bike  2021-12-10 21:43:32
# 632818  1BB5CF43B5DF7E05  classic_bike  2021-12-08 11:09:56
#
#                    ended_at          start_station_name start_station_id  \
# 0       2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1       2021-02-27 16:56:40                Newport Pkwy            JC008
# 2       2021-02-26 23:22:25              Journal Square            JC103
# 3       2021-02-24 17:16:09  Hoboken Ave at Monmouth St            JC105
# 4       2021-02-24 20:44:46  Hoboken Ave at Monmouth St            JC105
# ...                     ...                         ...              ...
# 632814  2021-12-16 17:22:53               Grove St PATH            JC005
# 632815  2021-12-07 17:15:02               Grove St PATH            JC005
# 632816  2021-12-18 09:55:55               Grove St PATH            JC005
# 632817  2021-12-10 21:49:04               Grove St PATH            JC005
# 632818  2021-12-08 11:14:58                     Hilltop            JC019
#
#                   end_station_name end_station_id  start_lat  start_lng  \
# 0                  Christ Hospital          JC034  40.735208 -74.046964
# 1                 Marin Light Rail          JC013  40.728744 -74.032108
# 2            Baldwin at Montgomery          JC020  40.733670 -74.062500
# 3       Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# 4       Hoboken Ave at Monmouth St          JC105  40.735208 -74.046963
# ...                            ...            ...        ...        ...
# 632814               Hamilton Park          JC009  40.719586 -74.043117
# 632815               Hamilton Park          JC009  40.719586 -74.043117
# 632816               Hamilton Park          JC009  40.719586 -74.043117
# 632817               Hamilton Park          JC009  40.719586 -74.043117
# 632818               Hamilton Park          JC009  40.731169 -74.057574
#
#           end_lat    end_lng member_casual
# 0       40.734786 -74.050444        member
# 1       40.714584 -74.042817        member
# 2       40.723659 -74.064194        member
# 3       40.735208 -74.046964        casual
# 4       40.735208 -74.046964        member
# ...           ...        ...           ...
# 632814  40.727596 -74.044247        member
# 632815  40.727596 -74.044247        member
# 632816  40.727596 -74.044247        member
# 632817  40.727596 -74.044247        member
# 632818  40.727596 -74.044247        member
#
# [632819 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
df.drop(['start_lat', 'start_lng','end_lat','end_lng'], axis=1, inplace=True)
df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28  2021-02-03 23:18:28
# 1  FD73FB85F008349D   docked_bike  2021-02-27 16:34:05  2021-02-27 16:56:40
# 2  39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04  2021-02-26 23:22:25
# 3  A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50  2021-02-24 17:16:09
# 4  75CC76EB9543764A   docked_bike  2021-02-24 20:44:16  2021-02-24 20:44:46
#
#            start_station_name start_station_id            end_station_name  \
# 0  Hoboken Ave at Monmouth St            JC105             Christ Hospital
# 1                Newport Pkwy            JC008            Marin Light Rail
# 2              Journal Square            JC103       Baldwin at Montgomery
# 3  Hoboken Ave at Monmouth St            JC105  Hoboken Ave at Monmouth St
# 4  Hoboken Ave at Monmouth St            JC105  Hoboken Ave at Monmouth St
#
#   end_station_id member_casual
# 0          JC034        member
# 1          JC013        member
# 2          JC020        member
# 3          JC105        casual
# 4          JC105        member

# %%
df['date'] = pd.to_datetime(df['started_at'])

# add a column for Year
df['year'] = df['date'].dt.year
# add a column for Month
df['month'] = df['date'].dt.month
# add a column for Day
df['day'] = df['date'].dt.day
# add a column for Day of the Year
df['dayofyear'] = df['date'].dt.dayofyear
# add a column for Day of the Year
df['hour'] = df['date'].dt.hour

df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28  2021-02-03 23:18:28
# 1  FD73FB85F008349D   docked_bike  2021-02-27 16:34:05  2021-02-27 16:56:40
# 2  39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04  2021-02-26 23:22:25
# 3  A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50  2021-02-24 17:16:09
# 4  75CC76EB9543764A   docked_bike  2021-02-24 20:44:16  2021-02-24 20:44:46
#
#            start_station_name start_station_id            end_station_name  \
# 0  Hoboken Ave at Monmouth St            JC105             Christ Hospital
# 1                Newport Pkwy            JC008            Marin Light Rail
# 2              Journal Square            JC103       Baldwin at Montgomery
# 3  Hoboken Ave at Monmouth St            JC105  Hoboken Ave at Monmouth St
# 4  Hoboken Ave at Monmouth St            JC105  Hoboken Ave at Monmouth St
#
#   end_station_id member_casual                date  year  month  day  \
# 0          JC034        member 2021-02-03 23:11:28  2021      2    3
# 1          JC013        member 2021-02-27 16:34:05  2021      2   27
# 2          JC020        member 2021-02-26 23:16:04  2021      2   26
# 3          JC105        casual 2021-02-24 16:51:50  2021      2   24
# 4          JC105        member 2021-02-24 20:44:16  2021      2   24
#
#    dayofyear  hour
# 0         34    23
# 1         58    16
# 2         57    23
# 3         55    16
# 4         55    20

# %%
df.to_csv("data/combined_data.csv")
